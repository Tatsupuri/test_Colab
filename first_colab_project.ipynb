# %% [markdown]
# # Googl Colabを用いた開発環境

# %% [markdown]
# ## 動機
# このプロジェクトは、Google Colaboratoryを用いた開発のテストとして作成した。
# 具体的には研究室で借りているPCにはグラボが積まれていないので、Colabを利用することにした。
#
# ここで、研究室以外でも作業ができるように、Githubを使ってプロジェクトを管理することにする。
#
# Googl Colabで新しくファイルを作成すると自分のgoogle Driveにファイルが作成される。
# Google　DriveのプロジェクトをPCにマウントするには、Googleのバックアップと同期というアプリを使うのが便利である。これでローカルのファイルと同様にしてGitで管理することができる。

# %%
import numpy as np
import torch
